# %%
# !git clone https://github.com/Alireza-Akhavan/object-detection-notebooks.git

# %% [markdown]
# This notebook is part of "Object detection course":
#     https://github.com/Alireza-Akhavan/object-detection-notebooks

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os
# %matplotlib inline

# %%
# define the base path to the input dataset and then use it to derive
# the path to the input images and annotation CSV files
BASE_PATH = "dataset2"
IMAGES_PATH = os.path.sep.join([BASE_PATH, "images"])
ANNOTS_PATH = os.path.sep.join([BASE_PATH, "annotations"])

# %% [markdown]
# initialize the list of data (images), class labels, target bounding box coordinates, and image paths

# %%
data = []
labels = []
bboxes = []
imagePaths = []

# %%
csvPaths = []
for (rootDir, dirNames, filenames) in os.walk(ANNOTS_PATH):
    # loop over the filenames in the current directory
    for filename in filenames:
        # determine the file extension of the current file
        ext = filename[filename.rfind("."):].lower()

        # check to see if the file is an image and should be processed
        if ext.endswith(".csv"):
            # construct the path to the image and yield it
            csvPath = os.path.join(rootDir, filename)
            csvPaths.append(csvPath)

csvPaths
# Out:
# ['dataset2\\annotations\\airplane.csv',
#  'dataset2\\annotations\\face.csv',
#  'dataset2\\annotations\\motorcycle.csv']

# %%
# loop over all CSV files in the annotations directory
for csvPath in csvPaths:
    # load the contents of the current CSV annotations file
    rows = open(csvPath).read().strip().split("\n")

    # loop over the rows
    for row in rows:
        # break the row into the filename, bounding box coordinates,
        # and class label
        row = row.split(",")
        (filename, startX, startY, endX, endY, label) = row

        # derive the path to the input image, load the image (in
        # OpenCV format), and grab its dimensions
        imagePath = os.path.sep.join([IMAGES_PATH, label, filename])
        image = cv2.imread(imagePath)
        (h, w) = image.shape[:2]

        # scale the bounding box coordinates relative to the spatial
        # dimensions of the input image
        startX = float(startX) / w
        startY = float(startY) / h
        endX = float(endX) / w
        endY = float(endY) / h

        # load the image and preprocess it
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)

        # update our list of data, class labels, bounding boxes, and
        # image paths
        data.append(image)
        labels.append(label)
        bboxes.append((startX, startY, endX, endY))
        imagePaths.append(imagePath)

# %%
# convert the data, class labels, bounding boxes, and image paths to
# NumPy arrays, scaling the input pixel intensities from the range
# [0, 255] to [0, 1]
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
imagePaths = np.array(imagePaths)

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
split = train_test_split(data, labels, bboxes, imagePaths, test_size=0.20, random_state=42)
# unpack the data split
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]
(trainPaths, testPaths) = split[6:]

# %%
# load the VGG16 network, ensuring the head FC layers are left off
vgg = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %%
# freeze all VGG layers so they will *not* be updated during the
# training process
vgg.trainable = False

# %%
# flatten the max-pooling output of VGG
flatten = vgg.output
flatten = Flatten()(flatten)

# construct a fully-connected layer header to output the predicted
# bounding box coordinates
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid", name="bounding_box")(bboxHead)

# construct a second fully-connected layer head, this one to predict
# the class label
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax", name="class_label")(softmaxHead)

# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(inputs=vgg.input, outputs=(bboxHead, softmaxHead))

# %%
# define a dictionary to set the loss methods -- categorical
# cross-entropy for the class label head and mean absolute error
# for the bounding box head
losses = {
    "class_label": "categorical_crossentropy",
    "bounding_box": "mean_squared_error",
}

# define a dictionary that specifies the weights per loss (both the
# class label and bounding box outputs will receive equal weight)
lossWeights = {
    "class_label": 1.0,
    "bounding_box": 1.0
}

# %%
# initialize the optimizer, compile the model, and show the model
# summary
opt = Adam(lr=1e-4)
model.compile(loss=losses, optimizer=opt, metrics=["accuracy"], loss_weights=lossWeights)

# %%
# construct a dictionary for our target training outputs
trainTargets = {
    "class_label": trainLabels,
    "bounding_box": trainBBoxes
}

# construct a second dictionary, this one for our target testing
# outputs
testTargets = {
    "class_label": testLabels,
    "bounding_box": testBBoxes
}

# train the network for bounding box regression and class label
# prediction
H = model.fit(
    trainImages, trainTargets,
    validation_data=(testImages, testTargets),
    batch_size=32,
    epochs=20,
    verbose=1)
# Out:
# Epoch 1/20
# 51/51 [==============================] - 63s 1s/step - loss: 0.2092 - bounding_box_loss: 0.0354 - class_label_loss: 0.1739 - bounding_box_accuracy: 0.7503 - class_label_accuracy: 0.9262 - val_loss: 0.0052 - val_bounding_box_loss: 0.0028 - val_class_label_loss: 0.0025 - val_bounding_box_accuracy: 0.8870 - val_class_label_accuracy: 1.0000
# Epoch 2/20
# 51/51 [==============================] - 58s 1s/step - loss: 0.0168 - bounding_box_loss: 0.0019 - class_label_loss: 0.0149 - bounding_box_accuracy: 0.8807 - class_label_accuracy: 0.9975 - val_loss: 0.0039 - val_bounding_box_loss: 0.0015 - val_class_label_loss: 0.0025 - val_bounding_box_accuracy: 0.8698 - val_class_label_accuracy: 0.9975
# Epoch 3/20
# 51/51 [==============================] - 58s 1s/step - loss: 0.0074 - bounding_box_loss: 0.0014 - class_label_loss: 0.0060 - bounding_box_accuracy: 0.8819 - class_label_accuracy: 0.9982 - val_loss: 0.0036 - val_bounding_box_loss: 0.0012 - val_class_label_loss: 0.0023 - val_bounding_box_accuracy: 0.8771 - val_class_label_accuracy: 0.9975
# Epoch 4/20
# 51/51 [==============================] - 59s 1s/step - loss: 0.0042 - bounding_box_loss: 0.0011 - class_label_loss: 0.0031 - bounding_box_accuracy: 0.8875 - class_label_accuracy: 0.9994 - val_loss: 0.0020 - val_bounding_box_loss: 0.0011 - val_class_label_loss: 8.7081e-04 - val_bounding_box_accuracy: 0.8722 - val_class_label_accuracy: 1.0000
# Epoch 5/20
# 51/51 [==============================] - 59s 1s/step - loss: 0.0080 - bounding_box_loss: 8.9026e-04 - class_label_loss: 0.0071 - bounding_box_accuracy: 0.8911 - class_label_accuracy: 0.9982 - val_loss: 0.0016 - val_bounding_box_loss: 0.0010 - val_class_label_loss: 6.0486e-04 - val_bounding_box_accuracy: 0.8796 - val_class_label_accuracy: 1.0000
# Epoch 6/20
# 51/51 [==============================] - 60s 1s/step - loss: 0.0029 - bounding_box_loss: 7.5625e-04 - class_label_loss: 0.0021 - bounding_box_accuracy: 0.8893 - class_label_accuracy: 0.9994 - val_loss: 0.0013 - val_bounding_box_loss: 9.3772e-04 - val_class_label_loss: 3.3180e-04 - val_bounding_box_accuracy: 0.8894 - val_class_label_accuracy: 1.0000
# Epoch 7/20
# 51/51 [==============================] - 60s 1s/step - loss: 0.0016 - bounding_box_loss: 6.3955e-04 - class_label_loss: 9.4901e-04 - bounding_box_accuracy: 0.8918 - class_label_accuracy: 1.0000 - val_loss: 0.0012 - val_bounding_box_loss: 8.6861e-04 - val_class_label_loss: 3.0960e-04 - val_bounding_box_accuracy: 0.8821 - val_class_label_accuracy: 1.0000
# Epoch 8/20
# 51/51 [==============================] - 60s 1s/step - loss: 0.0012 - bounding_box_loss: 5.5163e-04 - class_label_loss: 6.9213e-04 - bounding_box_accuracy: 0.8979 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 8.5425e-04 - val_class_label_loss: 2.6472e-04 - val_bounding_box_accuracy: 0.9091 - val_class_label_accuracy: 1.0000
# Epoch 9/20
# 51/51 [==============================] - 61s 1s/step - loss: 0.0020 - bounding_box_loss: 4.8505e-04 - class_label_loss: 0.0015 - bounding_box_accuracy: 0.9034 - class_label_accuracy: 0.9994 - val_loss: 0.0041 - val_bounding_box_loss: 8.1329e-04 - val_class_label_loss: 0.0033 - val_bounding_box_accuracy: 0.8993 - val_class_label_accuracy: 0.9975
# Epoch 10/20
# 51/51 [==============================] - 61s 1s/step - loss: 0.0013 - bounding_box_loss: 4.2612e-04 - class_label_loss: 8.4953e-04 - bounding_box_accuracy: 0.9096 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 8.1630e-04 - val_class_label_loss: 2.3785e-04 - val_bounding_box_accuracy: 0.8624 - val_class_label_accuracy: 1.0000
# Epoch 11/20
# 51/51 [==============================] - 61s 1s/step - loss: 0.0016 - bounding_box_loss: 3.8349e-04 - class_label_loss: 0.0013 - bounding_box_accuracy: 0.9102 - class_label_accuracy: 0.9994 - val_loss: 0.0011 - val_bounding_box_loss: 7.7700e-04 - val_class_label_loss: 3.4893e-04 - val_bounding_box_accuracy: 0.8747 - val_class_label_accuracy: 1.0000
# Epoch 12/20
# 51/51 [==============================] - 61s 1s/step - loss: 8.0575e-04 - bounding_box_loss: 3.4464e-04 - class_label_loss: 4.6111e-04 - bounding_box_accuracy: 0.9108 - class_label_accuracy: 1.0000 - val_loss: 0.0010 - val_bounding_box_loss: 7.7033e-04 - val_class_label_loss: 2.5242e-04 - val_bounding_box_accuracy: 0.8870 - val_class_label_accuracy: 1.0000
# Epoch 13/20
# 51/51 [==============================] - 61s 1s/step - loss: 6.9325e-04 - bounding_box_loss: 3.2025e-04 - class_label_loss: 3.7301e-04 - bounding_box_accuracy: 0.9133 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 7.5092e-04 - val_class_label_loss: 3.8558e-04 - val_bounding_box_accuracy: 0.8943 - val_class_label_accuracy: 1.0000
# Epoch 14/20
# 51/51 [==============================] - 61s 1s/step - loss: 6.1258e-04 - bounding_box_loss: 2.8220e-04 - class_label_loss: 3.3038e-04 - bounding_box_accuracy: 0.9213 - class_label_accuracy: 1.0000 - val_loss: 8.8160e-04 - val_bounding_box_loss: 7.6650e-04 - val_class_label_loss: 1.1510e-04 - val_bounding_box_accuracy: 0.9115 - val_class_label_accuracy: 1.0000
# Epoch 15/20
# 51/51 [==============================] - 61s 1s/step - loss: 4.2911e-04 - bounding_box_loss: 2.6593e-04 - class_label_loss: 1.6318e-04 - bounding_box_accuracy: 0.9207 - class_label_accuracy: 1.0000 - val_loss: 8.4863e-04 - val_bounding_box_loss: 7.4730e-04 - val_class_label_loss: 1.0133e-04 - val_bounding_box_accuracy: 0.8771 - val_class_label_accuracy: 1.0000
# Epoch 16/20
# 51/51 [==============================] - 61s 1s/step - loss: 6.0427e-04 - bounding_box_loss: 2.4008e-04 - class_label_loss: 3.6419e-04 - bounding_box_accuracy: 0.9194 - class_label_accuracy: 1.0000 - val_loss: 8.5335e-04 - val_bounding_box_loss: 7.2564e-04 - val_class_label_loss: 1.2771e-04 - val_bounding_box_accuracy: 0.8747 - val_class_label_accuracy: 1.0000
# Epoch 17/20
# 51/51 [==============================] - 61s 1s/step - loss: 4.7221e-04 - bounding_box_loss: 2.2186e-04 - class_label_loss: 2.5034e-04 - bounding_box_accuracy: 0.9244 - class_label_accuracy: 1.0000 - val_loss: 9.3895e-04 - val_bounding_box_loss: 7.1287e-04 - val_class_label_loss: 2.2608e-04 - val_bounding_box_accuracy: 0.8845 - val_class_label_accuracy: 1.0000
# Epoch 18/20
# 51/51 [==============================] - 61s 1s/step - loss: 3.2671e-04 - bounding_box_loss: 2.0274e-04 - class_label_loss: 1.2397e-04 - bounding_box_accuracy: 0.9244 - class_label_accuracy: 1.0000 - val_loss: 8.7355e-04 - val_bounding_box_loss: 7.4592e-04 - val_class_label_loss: 1.2763e-04 - val_bounding_box_accuracy: 0.8452 - val_class_label_accuracy: 1.0000
# Epoch 19/20
# 51/51 [==============================] - 61s 1s/step - loss: 3.1303e-04 - bounding_box_loss: 1.8882e-04 - class_label_loss: 1.2422e-04 - bounding_box_accuracy: 0.9317 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 7.1352e-04 - val_class_label_loss: 3.5801e-04 - val_bounding_box_accuracy: 0.8943 - val_class_label_accuracy: 1.0000
# Epoch 20/20
# 51/51 [==============================] - 61s 1s/step - loss: 3.3352e-04 - bounding_box_loss: 1.7537e-04 - class_label_loss: 1.5815e-04 - bounding_box_accuracy: 0.9317 - class_label_accuracy: 1.0000 - val_loss: 8.9279e-04 - val_bounding_box_loss: 7.1432e-04 - val_class_label_loss: 1.7847e-04 - val_bounding_box_accuracy: 0.9017 - val_class_label_accuracy: 1.0000

# %%
model.save('3.h5', save_format="h5")
with open('lb3.pickle', "wb") as f:
    f.write(pickle.dumps(lb))

# %%
# plot the total loss, label loss, and bounding box loss
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0, H.params['epochs'])
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))

# loop over the loss names
for (i, l) in enumerate(lossNames):
    # plot the loss for both the training and validation data
    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
    ax[i].set_title(title)
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Loss")
    ax[i].plot(N, H.history[l], label=l)
    ax[i].plot(N, H.history["val_" + l], label="val_" + l)
    ax[i].legend()

# save the losses figure and create a new figure for the accuracies
plt.tight_layout()

# create a new figure for the accuracies
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"], label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"], label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %% [markdown]
# Source:
#
# https://www.pyimagesearch.com/2020/10/12/multi-class-object-detection-and-bounding-box-regression-with-keras-tensorflow-and-deep-learning/
